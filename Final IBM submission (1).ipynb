# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:/Users/ostei/Desktop/Complete Tensorflow 2 and Keras Deep Learning Bootcamp/TF_2_Notebooks_and_Data/DATA/kc_house_data.csv")

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
updated_df = df[df['bedrooms'] < 3 ]

# %%
updated_df.head(100)
# Out:
#              id       date      price  bedrooms  bathrooms  sqft_living  \
# 2    5631500400  2/25/2015   180000.0         2       1.00          770
# 11   9212900260  5/27/2014   468000.0         2       1.00         1160
# 18     16000397  12/5/2014   189000.0         2       1.00         1200
# 23   8091400200  5/16/2014   252700.0         2       1.50         1070
# 31   2426039314  12/1/2014   280000.0         2       1.50         1190
# ..          ...        ...        ...       ...        ...          ...
# 753  8682300890  8/28/2014   699800.0         2       2.50         2380
# 757  9273200140  1/21/2015  1310000.0         2       2.25         3950
# 773  1623300160   5/6/2014   450000.0         2       2.00         1100
# 786  2688100071  4/15/2015   500000.0         2       1.00         1280
# 794  1623049062   3/4/2015   210000.0         2       1.00          750
#
#      sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
# Folium installed
# Libraries imported.

# %%
CLIENT_ID = 'JI5OUQZDG2VUJN1XQOUU4PDWRN2AQPT0HPTFMLLTTW3YJBJ3' # your Foursquare ID
CLIENT_SECRET = 'BC2NWYRFXUJ1UCDLPSGUTO0EBHJY0NSWMCREBYTYPZ3TG5KU' # your Foursquare Secret
VERSION = '20200712'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: JI5OUQZDG2VUJN1XQOUU4PDWRN2AQPT0HPTFMLLTTW3YJBJ3
# CLIENT_SECRET:BC2NWYRFXUJ1UCDLPSGUTO0EBHJY0NSWMCREBYTYPZ3TG5KU

# %%
venues_map = folium.Map(location=[47.414571, -122.17085], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.features.CircleMarker(
    [47.414571, -122.17085],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, long in zip(updated_df.lat, updated_df.long):
    folium.features.CircleMarker(
        [lat, long],
        radius=5,
        color='blue',
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
plt.figure(figsize=(12,8))
sns.distplot(df['price'])

# %%
plt.figure(figsize=(12,8))
sns.countplot(updated_df['bedrooms'])

# %%
updated_df.corr()['price']

#drawing a scatter plot with two features with high correlation 

plt.figure(figsize=(12,8))
sns.scatterplot(x='price',y='sqft_living',data=updated_df)

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x='bedrooms',y='price',data=df)

# %%
updated_df.corr()['price'].sort_values()
# Out:
# long            -0.055727
# zipcode         -0.031147
# month           -0.009857
# year             0.025255
# sqft_lot15       0.056414
# id               0.060359
# yr_renovated     0.064344
# yr_built         0.064555
# condition        0.066904
# sqft_lot         0.087743
# bedrooms         0.105407
# floors           0.172002
# waterfront       0.272824
# sqft_basement    0.340887
# lat              0.348405
# bathrooms        0.365869
# view             0.383350
# sqft_living15    0.505287
# sqft_above       0.537542
# grade            0.556985
# sqft_living      0.623682
# price            1.000000
# Name: price, dtype: float64

# %%
updated_df['date'] = pd.to_datetime(updated_df['date'])
# Out:
# C:\Users\ostei\anaconda3\envs\AI\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
updated_df['month'] = updated_df['date'].apply(lambda date:date.month)
# Out:
# C:\Users\ostei\anaconda3\envs\AI\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
updated_df['year'] = updated_df['date'].apply(lambda date:date.year)
# Out:
# C:\Users\ostei\anaconda3\envs\AI\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
plt.figure(figsize=(12,8))
updated_df.groupby('year').mean()['price'].plot()

# %% [markdown]
# Testing

# %%
X = updated_df[['grade','sqft_living']]
y = updated_df['price']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.4)
print (X_train.shape, y_train.shape)
print (X_test.shape, y_test.shape)
# Out:
# (1773, 2) (1773,)
# (1183, 2) (1183,)

# %%
from sklearn.linear_model import LinearRegression
clf = LinearRegression()

# %%
clf.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
predictions = clf.predict(X_test)

# %%
clf.score(X_test,y_test)
# Out:
# 0.47760711070781026

# %%
#plt.figure(figsize=(12,8))
#plt.scatter(y_test, predictions)
#plt.xlabel("True Values")
#plt.ylabel("Predictions")

import seaborn as sns; 
sns.set(color_codes=True)
plt.figure(figsize=(12,8))
#pred = sns.load_predictions("X_test")
#ax = sns.regplot(x="True Values", y="Predictions", data=pred)

sns.regplot(x=y_test, y=predictions, fit_reg=True);

#fig, ax = plt.subplots()
#for a in [y_test, predictions]:
    #sns.distplot(a, ax=ax, kde=False)
#ax.set_xlim([0, 1000000])
